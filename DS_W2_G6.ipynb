# %% [markdown]
# <a href="https://colab.research.google.com/github/rafavch/DS-Project/blob/master/DS_W2_G6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Analyze variables, fill in missing values, normalize extreme values.**

# %%
import pandas as pd
import numpy as np
cars_data = pd.read_csv (r'/content/sample_data/Automotive_2.csv')   #read the csv file (put 'r' before the path string to address any special characters in the path, such as '\'). Don't forget to put the file name at the end of the path + ".csv"
cars_data.head (5)
# Out:
#        dateCrawled                                               name  seller  \
# 0  3/26/2016 14:57  BMW_320d_DPFXenon_Tempomat_Sitzheizung_PDC_Kli...  privat
# 1  3/23/2016 20:57                   Renault_clio_mit_nagelneuen_T?!*  privat
# 2  3/19/2016 18:56                              VW_LUPO._1.1l_T?_3/18  privat
# 3  3/30/2016 12:51             Opel_Astra_Caravan_Sport_sehr_gepflegt  privat
# 4  3/26/2016 21:36              Ford_Focus_Turnier_1.6_TDCi_DPF_Trend  privat
#
#   offerType  price   abtest vehicleType yearOfRegistration gearbox powerPS  \
# 0   Angebot  10499  control   limousine               2006  manual     163
# 1   Angebot   1199     test  kleinwagen               2001  manual       0
# 2   Angebot   2750     test  kleinwagen               1999  manual      50
# 3   Angebot   3500  control       kombi               2004  manual     125
# 4   Angebot   7500  control       kombi               2012  manual     116
#
# ...

# %%
km = np.array(cars_data['kilometer'])
np.max(km)
# Out:
# 150000
